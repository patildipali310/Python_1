# %%
##Pandas

# %%
import pandas as pd
import numpy as np

# %%
dir(pd)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__deprecated_num_index_names',
#  '__dir__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
# ...

# %%
df=pd.read_csv(r"C:\Users\ADMIN\Documents\Data_Science & Python\Data_Science_Daily_Lecture\Students_Performance_knn.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
#List first 5 records
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # Hands on

# %%
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college           NaN
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
df.head(20)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6   female        group B                some college           NaN
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...

# %%
df['gender'].dtype
# Out:
# dtype('O')

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=1000, step=1),
#  Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#         'test preparation course', 'math score', 'reading score',
#         'writing score'],
#        dtype='object')]

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 8000

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.values
# Out:
# array([['female', 'group B', "bachelor's degree", ..., 72, 72, 74],
#        ['female', 'group C', 'some college', ..., 69, 90, 88],
#        ['female', 'group B', "master's degree", ..., 90, 95, 93],
#        ...,
#        ['female', 'group C', 'high school', ..., 59, 71, 65],
#        ['female', 'group D', 'some college', ..., 68, 78, 77],
#        ['female', 'group D', 'some college', ..., 77, 86, 86]],
#       dtype=object)

# %%
df.size
# Out:
# 8000

# %%
df.shape   # Row - column
len(df.columns)
# Out:
# 8

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df.describe().T
# Out:
#                 count    mean        std   min    25%   50%   75%    max
# math score     1000.0  66.089  15.163080   0.0  57.00  66.0  77.0  100.0
# reading score  1000.0  69.169  14.600192  17.0  59.00  70.0  79.0  100.0
# writing score  1000.0  68.054  15.195657  10.0  57.75  69.0  79.0  100.0

# %%
df.max()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12736\1151452817.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.max()
# gender                                     male
# race/ethnicity                          group E
# parental level of education    some high school
# test preparation course                    none
# math score                                  100
# reading score                               100
# writing score                               100
# dtype: object

# %%
df.min()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12736\3962516015.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.min()
# gender                                     female
# race/ethnicity                            group A
# parental level of education    associate's degree
# test preparation course                 completed
# math score                                      0
# reading score                                  17
# writing score                                  10
# dtype: object

# %%
print(df.mean())
print(df["math score"].mean())
print(df['reading score'].mean())
print(df['writing score'].mean())
# Out:
# math score       66.089
# reading score    69.169
# writing score    68.054
# dtype: float64
# 66.089
# 69.169
# 68.054
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12736\3128434584.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(df.mean())

# %%
df.median()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12736\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# math score       66.0
# reading score    70.0
# writing score    69.0
# dtype: float64

# %%
df.std()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12736\3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# math score       15.163080
# reading score    14.600192
# writing score    15.195657
# dtype: float64

# %%
df.sample(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 729    male        group C                some college      standard
# 216  female        group E          associate's degree  free/reduced
# 20     male        group D                 high school      standard
# 261    male        group C                some college      standard
# 433  female        group A            some high school  free/reduced
# 987    male        group E            some high school      standard
# 736    male        group C          associate's degree      standard
# 221    male        group B          associate's degree      standard
# 763  female        group B                 high school      standard
# 42   female        group B          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 729                    none          53             39             37
# ...

# %%
df.std()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12736\3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# math score       15.163080
# reading score    14.600192
# writing score    15.195657
# dtype: float64

# %%
#print(df.head(50).mean())
#Or
df1 = df.head(50)
df1.mean()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12736\1584950331.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.mean()
# math score       62.84
# reading score    67.94
# writing score    66.44
# dtype: float64

# %%
df.mean()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12736\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# math score       66.089
# reading score    69.169
# writing score    68.054
# dtype: float64

# %%
#Summary   
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df['math score'].count()
# Out:
# 1000

# %%
#df.gender.describe()
#Or
df['gender'].describe()
# Out:
# count       1000
# unique         2
# top       female
# freq         518
# Name: gender, dtype: object

# %%
df = df.rename(columns={'math score': 'math_score', 'reading score': 'reading_score', 'writing score': 'writing_score'})

# %%
df.math_score.mean()   # Average
# Out:
# 66.089

# %%
df_math=df.groupby(['math_score'])

# %%
df_math.mean()
# Out:
#             reading_score  writing_score
# math_score
# 0               17.000000      10.000000
# 8               24.000000      23.000000
# 18              32.000000      28.000000
# 19              38.000000      32.000000
# 22              39.000000      33.000000
# ...                   ...            ...
# 96              95.333333      97.000000
# 97              91.833333      90.500000
# 98              91.000000      93.000000
# 99              93.333333      90.333333
# 100             97.857143      96.428571
#
# [81 rows x 2 columns]

# %%
df.groupby('gender')[['math_score']].mean()  # 2D o/p
# Out:
#         math_score
# gender
# female   63.633205
# male     68.728216

# %%
df.groupby('gender')['reading_score'].mean()  # O/p data structure will be series
# Out:
# gender
# female    72.608108
# male      65.473029
# Name: reading_score, dtype: float64

# %%
df.groupby(['gender'], sort = False)[['writing_score']].mean()
# Out:
#         writing_score
# gender
# female      72.467181
# male        63.311203
